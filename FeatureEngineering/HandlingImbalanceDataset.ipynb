# %% [markdown]
# <a href="https://colab.research.google.com/github/UmarKhattab09/DataPipeline/blob/main/FeatureEngineering/HandlingImbalanceDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### UPSAMPLING & DOWNSAMPLING

# %%
import numpy as np
import pandas as pd

np.random.seed(42)

n_samples=1000
classratio=0.9
class0 = int(n_samples*classratio)
class1 = n_samples-class0

# %%
### Creating a Dataset
pd1 = pd.DataFrame({
    "feature1": np.random.normal(loc=0,scale=1,size=class0),
    "feature2":np.random.normal(loc=0,scale=1,size=class0),
    "target":[0]*class0
})
### Creating a Dataset
pd2 = pd.DataFrame({
    "feature1": np.random.normal(loc=0,scale=1,size=class1),
    "feature2":np.random.normal(loc=0,scale=1,size=class1),
    "target":[1]*class1
})
df = pd.concat([pd1,pd2]).reset_index(drop=True)

# %%
df
# Out:
#      feature1  feature2  target
# 0   -0.188202  1.227274       0
# 1   -0.103587 -1.210161       0
# 2   -0.213875  0.438579       0
# 3    0.970316 -1.370027       0
# 4    0.418760  1.065376       0
# ..        ...       ...     ...
# 995 -0.500261 -0.660834       1
# 996 -0.516117 -1.572989       1
# 997  2.124556 -1.052547       1
# 998 -2.773815  0.994299       1
# 999 -0.179620  0.254731       1
#
# [1000 rows x 3 columns]

# %%
df['target'].value_counts()
# Out:
# target
# 0    900
# 1    100
# Name: count, dtype: int64

# %% [markdown]
# ### UpSampling : Converting the Minority O/P to Major by adding random outputs

# %%
dfminor= df[df['target']==1]
dfmajor= df[df['target']==0]

# %%
from sklearn.utils import resample
dfminor_upsample=resample(dfminor,replace=True,
         n_samples=len(dfmajor),
         random_state=42)

# %%
dfminor_upsample.head()
# Out:
#      feature1  feature2  target
# 951  0.475335  1.917259       1
# 992 -0.602624 -0.755499       1
# 914  2.288791 -1.177226       1
# 971 -0.305954  0.029796       1
# 960 -0.605680 -1.532684       1

# %%
df_upsample = pd.concat([dfmajor,dfminor_upsample])
df_upsample['target'].value_counts()
# Out:
# target
# 0    900
# 1    900
# Name: count, dtype: int64

# %% [markdown]
# ### Down Sampling: Convert the major o/p into minor

# %%
### Creating a Dataset
pd1 = pd.DataFrame({
    "feature1": np.random.normal(loc=0,scale=1,size=class0),
    "feature2":np.random.normal(loc=0,scale=1,size=class0),
    "target":[0]*class0
})
### Creating a Dataset
pd2 = pd.DataFrame({
    "feature1": np.random.normal(loc=0,scale=1,size=class1),
    "feature2":np.random.normal(loc=0,scale=1,size=class1),
    "target":[1]*class1
})
df = pd.concat([pd1,pd2]).reset_index(drop=True)

# %%
### UpSAMPLING : Creating Artifical Points to create Balance Dataset
dfminor= df[df['target']==1]
dfmajor= df[df['target']==0]

# %%
from sklearn.utils import resample
dfmajor_downsample=resample(dfmajor,replace=False,
         n_samples=len(dfminor),
         random_state=42)

dfmajor_downsample.shape
# Out:
# (100, 3)

# %%
df_upsample = pd.concat([dfminor,dfmajor_downsample])
df_upsample['target'].value_counts()
# Out:
# target
# 1    100
# 0    100
# Name: count, dtype: int64
